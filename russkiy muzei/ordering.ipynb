# %%
import pandas as pd

# %%
df = pd.read_csv("russian_museum_exhibitions_2014_2026_updated.csv")

# %%
df
# Out:
#             museum                                   place  \
# 0    Русский музей         Михайловский (Инженерный) замок
# 1    Русский музей         Михайловский (Инженерный) замок
# 2    Русский музей                            Корпус Бенуа
# 3    Русский музей                            Корпус Бенуа
# 4    Русский музей                            Корпус Бенуа
# ..             ...                                     ...
# 646  Русский музей                     Михайловский дворец
# 647  Русский музей  Восточный павильон Михайловского замка
# 648  Русский музей                     Михайловский дворец
# 649  Русский музей                        Мраморный дворец
# 650  Русский музей                        Мраморный дворец
#
#                                                  title  \
# 0    Степан Эрьзя – скульптор мира. К 150-летию со ...
# 1        Эпоха Императора Александра III и её наследие
# 2                         Архип Куинджи. Иллюзия света
# ...

# %%
df1 = df.sort_values(by='year')
df1
# Out:
#             museum                                   place  \
# 620  Русский музей         Михайловский (Инженерный) замок
# 604  Русский музей         Михайловский (Инженерный) замок
# 625  Русский музей                     Михайловский дворец
# 624  Русский музей                              Летний сад
# 623  Русский музей                        Мраморный дворец
# ..             ...                                     ...
# 23   Русский музей                           Русский музей
# 22   Русский музей   Западный павильон Михайловского замка
# 21   Русский музей  Восточный павильон Михайловского замка
# 19   Русский музей                           Русский музей
# 0    Русский музей         Михайловский (Инженерный) замок
#
#                                                  title  \
# 620  Искусство как профессия. Собрание Майи и Анато...
# 604                         Дмитрий Шувалов. 1932-2013
# 625      Цветы и натюрморты Александра Бенуа Ди Стетто
# ...

# %%
df1.to_csv("russian_museum_exhibitions_2014_2026_updated_ordered.csv", index=False)
